# %% [markdown]
# <a href="https://colab.research.google.com/github/JacopoPassaro95/Python-Projects/blob/main/SCRAPER~TOOL_Project_for_Internship_offers_Jacopo_Passaro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Scraper~tool for internship offers with strings and regular expressions
# As an aspiring Data Scientist, I am interested in monitoring some Linkedin internships offers just to have an idea on what I am going to apply during next months.
# ###Let's try to do it in a funny automated way!

# %%
# Environment

import requests
import re
import random as rnd
import time
import pandas as pd

# %%
### Understanding Linkedin URL for job search
##By directly formatting URL it is possible to retrieve the offer page without manipulating anything else
# LinkedIn url for directly gettin Internship offers page

#  https://www.linkedin.com/jobs/search?
#  keywords=Data%20Science
#  &location=Milan%2C%20Lombardy%2C%20Italy
#  &locationId=
#  &geoId=100881402
#  &f_TPR=
#  &f_JT=I
#  &position=1
#  &pageNum=0

# %%
### How many offers are there ?
results_pattern = '<div class="jobs-search-results-list__subtitle><span>(.*?)</span>'

# %%
results_match = re.search(results_pattern, lin_html).group().strip()

# %%
print(results_match)

# %%
### Automatic formatting function for Linkedin URL according to desired queries
### This function fill Linkedin url with desired queries formatted in the correct way for internships research
def URLformat(keyword='', area='', job_type = ''):

  keyword = input("Please insert keywords for LinkedIn search: ")
  area = input("Where would you like to find this offer? ")
  job_type = input("Insert job type: F for full time, P for part-time, C for contractor, I for stages/internships ")

  # Error Message in case of missing query inputs and function immediate recall

  if keyword=='' or area=='' or job_type == '':

    print('Error: the words you have inserted are not correct, please try again')
    return  URLformat()

  # Then, replace function is used to fill
  # spaces with %20 and commas with %2C%20 thus formatting keyword and location inputs for the URL.
  # These replacements are necessary to ensure proper URL encoding

  search_url = keyword.replace(" ", "%20")

  if ", " in area:
    area_url = area.replace(", ", "%2C%20")
  else:
    area_url = area.replace(" ", "%20")

    # The linkedin_url variable ("f-string" form) contains variables of specified keywords
    # and location (as query parameters). This URL is so setted to perform a job search on LinkedIn.

  linkedin_url =f'https://www.linkedin.com/jobs/search?keywords={search_url}&location={area_url}&f_JT={job_type}&trk=public_jobs_jobs-search-bar_search-submit&position=1&pageNum=0'

  return linkedin_url

# %%
linkedin_url = URLformat()
# Out:
# Please insert keywords for LinkedIn search: data science
# Where would you like to find this offer? Milan, Lombardy, Italy
# Insert job type: F for full time, P for part-time, C for contractor, I for stages/internships I

# %%
print(linkedin_url)
# Out:
# https://www.linkedin.com/jobs/search?keywords=data%20science&location=Milan%2C%20Lombardy%2C%20Italy&f_JT=I&trk=public_jobs_jobs-search-bar_search-submit&position=1&pageNum=0

# %%
### Detecting key elements in html string
## "Tilde" indicates the string content to be extracted

# Datetime offer pubblication -> <time class="job-search-card__listdate" datetime=" ~ ">

# Offer Title pattern -> "<h3 class="base-search-card__title"> ~ </h3>"

# Company name pattern -> "<h4 ... > ~ </h4>"

# Link to offer path -> "< ... base-card__full-link ... href= ~ >"

# Offer Description from offer link -> <div class="show-more-less-html__markup .."> ~ </div>

# %%
### Scraping function for offer cards relevant information
## Once finished its work, the function will return a built in dedicated dataset

def LINternScrape(url):

  #1. Get page and check for HTTP correct response
  lin_page = requests.get(url)

  print(lin_page.status_code,lin_page.headers['content-type'])
  if lin_page.status_code != 200:
    print("ERROR: Unsuccessfull HTTP response! Try again")
    return LINternScrape() # 200 value indicates Successfull response


  #2. Store page content in a string variable

  lin_html = lin_page.text

  #3. Bulding lists of all relevant information with regular expression

   #a Datetime
  dates = []
  dat_pattern ='<time class=".*?" datetime="(.*?)">'
  datetimes =  re.findall(dat_pattern, lin_html, re.DOTALL)

  # re.findall returns a list of tuples containing all the matched objects within html string

  for date in datetimes:
    dates.append(date)

   #b Offer Title
  titles = []
  offer_title_pattern = '<h3(.*?)>(.*?)</h3>'
  offer_titles = re.findall(offer_title_pattern, lin_html, re.DOTALL)

  # It is necessary to iterate tuples thus accessing and isolating the second element [1] that corresponds to offer title
  # Linkedin pages show 25 offers per time, then a while condition avoids addition of other confusing elements

  i = 0
  while offer_titles and i <= 24:
    offer_title = offer_titles[i][1].strip()  #Access through indexing tuple objects in a list
    titles.append(offer_title)
    i = i + 1

   #c Companies
  companies = []

  company_pattern = "<h4(.*?)>(.*?)</h4>"
  offer_companies = re.findall(company_pattern, lin_html, re.DOTALL)

  for company_match in offer_companies:
    company = company_match[1]
    company = re.sub("<.*?>", "", company).strip()
    companies.append(company)

   #d Path to offer page
  paths = []

  pattern = 'href="(https://it.linkedin.com/jobs/view/.*?)"'
  links = re.findall(pattern, lin_html, re.DOTALL)

  for path in links:
  #No need to manipulate string, just retrieve element
    paths.append(path)

  #4. Create a data frame of all scraped information

  Internships = pd.DataFrame({
    'Date': dates,
    'Company': companies,
    'Title': titles,
    'Link': paths
})

  return Internships

# %%
LINternScrape(linkedin_url)
# Out:
# 200 text/html; charset=utf-8
#           Date                     Company  \
# 0   2023-06-05                     De Nora
# 1   2023-06-25   TalentKompass Deutschland
# 2   2023-06-13                         BIP
# 3   2023-06-25   TalentKompass Deutschland
# 4   2023-06-21                     Pirelli
# 5   2023-06-25   TalentKompass Deutschland
# 6   2023-06-25   TalentKompass Deutschland
# 7   2023-06-15                     Pirelli
# 8   2023-05-18  Samsung Electronics Italia
# 9   2023-06-23                         BIP
# 10  2023-06-15                   Corporate
# 11  2023-06-21                 Snam S.p.A.
# 12  2023-06-08              Nucleus Agency
# 13  2023-06-15                   Corporate
# 14  2023-05-23                         BIP
# 15  2023-06-15     The Kraft Heinz Company
# 16  2023-04-30  Samsung Electronics Italia
# 17  2023-06-12              DOUGLAS ITALIA
# 18  2023-05-27  Samsung Electronics Italia
# 19  2023-03-24                         BIP
# 20  2023-06-01                       IQVIA
# 21  2023-06-14                  KPMG Italy
# 22  2023-06-01                       IQVIA
# 23  2023-06-11                        CRIF
# 24  2023-06-04                 Fineco Bank
#
#                                                 Title  \
# 0                       Internship R&amp;D Researcher
# 1   Junior Data Analyst (Remote Internship – Data ...
# 2                      Junior consultant - Internship
# 3    Junior Python Developer (Remote Internship – IT)
# 4        Internship - Marketing &amp; Product Analyst
# 5         Junior Business Analyst (Remote Internship)
# 6   Junior Market Analyst (Remote Internship – Mar...
# 7        Internship - Logistic Reporting Professional
# 8          E-commerce Operations Support (INTERNSHIP)
# 9                   Digital Transformation Internship
# 10            Business Analyst Retail EMEA Internship
# 11                          Strategic Planning Intern
# 12                                Stage Web Analytics
# 13               Product Manager Wholesale Internship
# 14  Executive Assistant (Corporate Internal Function)
# 15                          Commercial Finance Intern
# 16                        MX-SCM Support (INTERNSHIP)
# 17                         Stage Supply Chain Support
# 18  DtC Operations/Logistics Analyst Support (INTE...
# 19           Internal Communication Senior Specialist
# 20             Pricing &amp; Market Access internship
# 21                          Audit - Technician Intern
# 22                                     Payroll Intern
# 23                         Corporate Marketing Intern
# 24                  Audit Specialist – Internal Audit
#
#                                                  Link
# 0   https://it.linkedin.com/jobs/view/internship-r...
# 1   https://it.linkedin.com/jobs/view/junior-data-...
# 2   https://it.linkedin.com/jobs/view/junior-consu...
# 3   https://it.linkedin.com/jobs/view/junior-pytho...
# 4   https://it.linkedin.com/jobs/view/internship-m...
# 5   https://it.linkedin.com/jobs/view/junior-busin...
# 6   https://it.linkedin.com/jobs/view/junior-marke...
# 7   https://it.linkedin.com/jobs/view/internship-l...
# 8   https://it.linkedin.com/jobs/view/e-commerce-o...
# 9   https://it.linkedin.com/jobs/view/digital-tran...
# 10  https://it.linkedin.com/jobs/view/business-ana...
# 11  https://it.linkedin.com/jobs/view/strategic-pl...
# 12  https://it.linkedin.com/jobs/view/stage-web-an...
# 13  https://it.linkedin.com/jobs/view/product-mana...
# 14  https://it.linkedin.com/jobs/view/executive-as...
# 15  https://it.linkedin.com/jobs/view/commercial-f...
# 16  https://it.linkedin.com/jobs/view/mx-scm-suppo...
# 17  https://it.linkedin.com/jobs/view/stage-supply...
# 18  https://it.linkedin.com/jobs/view/dtc-operatio...
# 19  https://it.linkedin.com/jobs/view/internal-com...
# 20  https://it.linkedin.com/jobs/view/pricing-mark...
# 21  https://it.linkedin.com/jobs/view/audit-techni...
# 22  https://it.linkedin.com/jobs/view/payroll-inte...
# 23  https://it.linkedin.com/jobs/view/corporate-ma...
# 24  https://it.linkedin.com/jobs/view/audit-specia...

# %%
Internships = LINternScrape(linkedin_url)
# Out:
# 200 text/html; charset=utf-8

# %%
### Scraping Descriptions from each Internship offer page with Descrape function
## Once finished all descriptions will be added to Internships dataset
def Descrape():

  descriptions = []

  for link in Internships["Link"]:


    #offer_link = Internships["Link"][link]

    offer_page = requests.get(link)
    print(offer_page.status_code, offer_page.headers['content-type'], "Description correctly scraped!")

    offer_html = offer_page.text

    description_pattern = '<div class="show-more-less-html__markup (.*?)>(.*?)</div>'

  # re.search() scans all the string looking for the first location where pattern produces the first match returning a "match object"

    description_match = re.search(description_pattern, offer_html, re.DOTALL).group(2).strip()

  # re.sub() to remove all the tags and return only description text.

    description = re.sub("<.*?>", "", description_match)
    descriptions.append(description)

  # IMPORTANT : Avoid too many HTTP requests at the same time
  # Suspend running code for 6 plus 1 to 3 random seconds simulating human behaviour

    time.sleep(5+rnd.randint(1,3))


    #print(f'The description of the {Internships[link]} offer link has been retrieved! Please wait 6 and few more seconds for another ')

    #print(description)
  print("All descriptions have been stored, thank you for waiting !")

  # Add scraped description to Internships dataset
  Internships['Description'] = descriptions

  # Get final Internship dataset result
  return Internships

# %%
Descrape()
# Out:
# 200 text/html; charset=utf-8 Description correctly scraped!
# 200 text/html; charset=utf-8 Description correctly scraped!
# 200 text/html; charset=utf-8 Description correctly scraped!
# 200 text/html; charset=utf-8 Description correctly scraped!
# 200 text/html; charset=utf-8 Description correctly scraped!
# 200 text/html; charset=utf-8 Description correctly scraped!
# 200 text/html; charset=utf-8 Description correctly scraped!
# 200 text/html; charset=utf-8 Description correctly scraped!
# 200 text/html; charset=utf-8 Description correctly scraped!
# 200 text/html; charset=utf-8 Description correctly scraped!
# 200 text/html; charset=utf-8 Description correctly scraped!
# 200 text/html; charset=utf-8 Description correctly scraped!
# 200 text/html; charset=utf-8 Description correctly scraped!
# 200 text/html; charset=utf-8 Description correctly scraped!
# 200 text/html; charset=utf-8 Description correctly scraped!
# 200 text/html; charset=utf-8 Description correctly scraped!
# 200 text/html; charset=utf-8 Description correctly scraped!
# 200 text/html; charset=utf-8 Description correctly scraped!
# 200 text/html; charset=utf-8 Description correctly scraped!
# 200 text/html; charset=utf-8 Description correctly scraped!
# 200 text/html; charset=utf-8 Description correctly scraped!
# 200 text/html; charset=utf-8 Description correctly scraped!
# 200 text/html; charset=utf-8 Description correctly scraped!
# 200 text/html; charset=utf-8 Description correctly scraped!
# 200 text/html; charset=utf-8 Description correctly scraped!
# All descriptions have been stored, thank you for waiting !
#           Date                     Company  \
# 0   2023-06-25   TalentKompass Deutschland
# 1   2023-06-15                   Corporate
# 2   2023-05-24                       IQVIA
# 3   2023-06-25   TalentKompass Deutschland
# 4   2023-06-25   TalentKompass Deutschland
# 5   2023-06-25   TalentKompass Deutschland
# 6   2023-06-21                     Pirelli
# 7   2023-06-15                     Pirelli
# 8   2023-06-08              Nucleus Agency
# 9   2023-06-05                     De Nora
# 10  2023-06-13                         BIP
# 11  2023-06-23                         BIP
# 12  2023-06-12              DOUGLAS ITALIA
# 13  2023-06-21                 Snam S.p.A.
# 14  2023-06-21                    Deloitte
# 15  2023-05-27  Samsung Electronics Italia
# 16  2023-05-26                ACCA Careers
# 17  2023-05-18  Samsung Electronics Italia
# 18  2023-04-30  Samsung Electronics Italia
# 19  2023-06-15                   Corporate
# 20  2023-05-24                       IQVIA
# 21  2023-06-15     The Kraft Heinz Company
# 22  2023-06-19                         BIP
# 23  2023-06-14                  KPMG Italy
# 24  2023-06-11                        CRIF
#
#                                                 Title  \
# 0   Junior Data Analyst (Remote Internship – Data ...
# 1             Business Analyst Retail EMEA Internship
# 2              Pricing &amp; Market Access internship
# 3         Junior Business Analyst (Remote Internship)
# 4   Junior Market Analyst (Remote Internship – Mar...
# 5    Junior Python Developer (Remote Internship – IT)
# 6        Internship - Marketing &amp; Product Analyst
# 7        Internship - Logistic Reporting Professional
# 8                                 Stage Web Analytics
# 9                       Internship R&amp;D Researcher
# 10                     Junior consultant - Internship
# 11                  Digital Transformation Internship
# 12                         Stage Product Data Support
# 13                          Strategic Planning Intern
# 14  Senior Consultant - Data Scientist MLops - Cor...
# 15  DtC Operations/Logistics Analyst Support (INTE...
# 16                                     Finance Intern
# 17         E-commerce Operations Support (INTERNSHIP)
# 18                        MX-SCM Support (INTERNSHIP)
# 19               Product Manager Wholesale Internship
# 20                                     Payroll Intern
# 21                          Commercial Finance Intern
# 22  Stage/Consultant PMO Digital Payments_Banking_...
# 23                          Audit - Technician Intern
# 24                         Corporate Marketing Intern
#
#                                                  Link  \
# 0   https://it.linkedin.com/jobs/view/junior-data-...
# 1   https://it.linkedin.com/jobs/view/business-ana...
# 2   https://it.linkedin.com/jobs/view/pricing-mark...
# 3   https://it.linkedin.com/jobs/view/junior-busin...
# 4   https://it.linkedin.com/jobs/view/junior-marke...
# 5   https://it.linkedin.com/jobs/view/junior-pytho...
# 6   https://it.linkedin.com/jobs/view/internship-m...
# 7   https://it.linkedin.com/jobs/view/internship-l...
# 8   https://it.linkedin.com/jobs/view/stage-web-an...
# 9   https://it.linkedin.com/jobs/view/internship-r...
# 10  https://it.linkedin.com/jobs/view/junior-consu...
# 11  https://it.linkedin.com/jobs/view/digital-tran...
# 12  https://it.linkedin.com/jobs/view/stage-produc...
# 13  https://it.linkedin.com/jobs/view/strategic-pl...
# 14  https://it.linkedin.com/jobs/view/senior-consu...
# 15  https://it.linkedin.com/jobs/view/dtc-operatio...
# 16  https://it.linkedin.com/jobs/view/finance-inte...
# 17  https://it.linkedin.com/jobs/view/e-commerce-o...
# 18  https://it.linkedin.com/jobs/view/mx-scm-suppo...
# 19  https://it.linkedin.com/jobs/view/product-mana...
# 20  https://it.linkedin.com/jobs/view/payroll-inte...
# 21  https://it.linkedin.com/jobs/view/commercial-f...
# 22  https://it.linkedin.com/jobs/view/stage-consul...
# 23  https://it.linkedin.com/jobs/view/audit-techni...
# 24  https://it.linkedin.com/jobs/view/corporate-ma...
#
#                                           Description
# 0   LOCATION: Remote WorkSCHEDULE: Part-timeAre yo...
# 1   Date: Jun 15, 2023Brand: CorporateLocation:Mil...
# 2   We are currently looking for an interns to joi...
# 3   LOCATION: Remote WorkSCHEDULE: Part-timeAre yo...
# 4   LOCATION: Remote WorkSCHEDULE: Part-timeAre yo...
# 5   LOCATION: Remote WorkSCHEDULE: Part-timeAre yo...
# 6   Job description:La posizione si colloca all'in...
# 7   Job description:La risorsa sarà inserita all'i...
# 8   Siamo alla ricerca di uno/una stagista full ti...
# 9   For our R&amp;D Italy Department, we are seeki...
# 10  Entra nel nostro mondo.Trasforma insieme a noi...
# 11  Entra nel nostro mondo.Trasforma insieme a noi...
# 12  Il Gruppo Douglas, con oltre 2000 profumerie i...
# 13  “Snam è il primo operatore europeo nel traspor...
# 14  RISK ADVISORYSenior Consultant – Data Scientis...
# 15  Position SummaryJob PurposeThe DtC Operations/...
# 16  Amazon.Job SummaryFinance InternAt Amazon, we ...
# 17  Position Summarye-Commerce operations: Manage ...
# 18  Position SummaryGive the correct support to co...
# 19  Date: Jun 15, 2023Brand: CorporateLocation:Mil...
# 20  IQVIA is a leading global provider of advanced...
# 21  General information  All posting locations  Mi...
# 22  Entra nel nostro mondo.Trasforma insieme a noi...
# 23  Hai conseguito il diploma in ambito tecnico-ec...
# 24  The applicant will report directly to the Corp...

# %%
### In case you are interested in just one or some descriptions after a first look to the dataset
def OneDescrape(index = None):
  index = int(input("Please insert position index of the description you want to scrape: "))

  if index > len(Internships):
    print("ERROR! Please insert a number between 1 and 25 ")
    return OneDescrape(index)

  descr_page = requests.get(Internships["Link"][index])
  descr_html = descr_page.text

  descr_pat = '<div class="show-more-less-html__markup (.*?)>(.*?)</div>'

  # re.search() scans all the string looking for the first location where pattern produces the first match returning a "match object"

  descr_match = re.search(descr_pat, descr_html, re.DOTALL).group(2).strip()

  # re.sub() to remove all the tags and return only description text.

  description = re.sub("<.*?>", "", descr_match)

  return description

# %%
### Just looking at an interesting offer description
eidosmedia = OneDescrape()
eidosmedia
# Out:
# Please insert position index of the description you want to scrape: 1
# 'We are looking for a Machine Learning Stageur for a 6 months internship experience joining the Engineering department.This Job-Ad is also open to persons belonging to protected categories – pursuant to Law 68/1999.Company ProfileWe at Eidosmedia are world leader in content management and digital publishing solutions. Our software covers the entire lifecycle of content, from authoring, management, workflow, design, to sharing, publishing and delivery, with open technologies and modern frameworks.We are innovators and disruptors, and we help our customers maximize the productivity and flexibility of their operations through the application of modern, digital technologies.What you will doThe Intern - in close collaboration with the Engineering Team - will be involved in activities that will cover different topics such as:Learn how international newspapers are being producedHelp the Team to build a complete and unbiased Dataset of publishing data from our customersUse his programming knowledge to build an innovative ML process based on the DatasetParticipate in developing a brand new cutting-edge predictive publishing softwareExtract, Transform and Load large production dataset to for the implementation of an analytics solution.What we offerContinuous Learning: We encourage and support continuing education, offer training to enhance job and management related skills and provide a working environment where learning and development takes place to help all employees in their job pathsSmart working and flexible working hours: dWe embrace flexibility and a balanced hybrid working model: plenty of focus time working from home as well as in-person collaboration that fosters trust, unlocks creativity, and accelerates innovation. The best of both worlds!International context: We are a global reality, and you will deal with people all over the worldEnthusiasm: We love what we do and we love doing it well. Our enthusiasm drives us to take pride and pleasure in the routine delivery of excellence.People-Centric Culture: Our people are our most valuable resource. We aim to create an environment where everyone can reach his/her full potential.Personal profile:Computer Science / Engineering / Scientific degree with Machine Learning hands-on experience (thesis, exam, project..)Programming Language: Python, nice to have JavaKnowledge of Data modeling for Machine LearningKnowledge of a Machine Learning frameworw: PyTorch or TensorflowNice to have: Reinforcement Learning knowledgeMore about usEidosmedia welcomes diversity among its people: whatever their race, religion, age, sex or sexual orientation, everybody’s contribution is valued equally in an atmosphere of mutual respect and regard.If you think you have what it takes to succeed in this role then apply immediately!'
